# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea1/impares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### impares.py
# Este código pide ingresar una cantidad de iteraciones e imprime un contador. Contiene secciones comentadas que evalúan números pares e impares, y calculan cubos.
#
# **Explicación paso a paso:**
# * `# for i in range (1,21): ...`: Código comentado con ejemplos para verificar pares/impares ($i \pmod 2 == 0$) y elevar al cubo ($i^3$).
# * `times = input("Enter a number of times: ")`: Pide la cantidad de iteraciones.
# * `times = float(times)` / `times = int(times)`: Convierte la entrada primero a flotante y luego a entero.
# * `print(type(times))` / `print(times)`: Muestra el tipo y valor de `times`.
# * `if times == 0:` / `print("Don't do anything")`: Si la cantidad de iteraciones es cero, no hace nada.
# * `else:` / `for i in range(1,times+1):` / `print("i = ", i)`: Si es mayor a cero, realiza un ciclo del 1 al valor ingresado e imprime el índice `i`.

# %%
# for i in range (1,21):
#     residual = i%2
#     if residual == 0:
#         print(f'{i} is even')
#     else:
#         #print(f'{i} is odd')
#         print(str(i) + ' is odd')

# for i in range (0,6):
#     result = i**3
#     print(result)

times = input("Enter a number of times: ")
times = float(times)
times = int(times)
print(type(times))
print(times)

if times == 0:
    print("Don't do anything")
else:
    for i in range(1,times+1):
        print("i = ", i)
