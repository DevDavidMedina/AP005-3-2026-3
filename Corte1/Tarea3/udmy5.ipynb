# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy5

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("Nba Teams.xlsx")`: Carga el archivo local `Nba Teams.xlsx` en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba["Name"]

# %% [markdown]
# * `nba["Name"]`: Extrae y muestra la columna `"Name"` como una Serie de Pandas.

# %%
nba["Salary"]

# %% [markdown]
# * `nba["Salary"]`: Extrae y selecciona la columna `"Salary"` del DataFrame `nba`.

# %%
nba.Name

# %% [markdown]
# * `nba.Name`: Accede a la columna `"Name"` del DataFrame `nba` utilizando la notación de punto (acceso por atributo).
