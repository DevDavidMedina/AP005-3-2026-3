# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy17__Optimizaci_n_de_base_de_datos_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy17 (Optimización de base de datos)

# %%
#Optimizing dataset

# %% [markdown]
# * `#Optimizing dataset`: Comentario que indica el inicio de la sección de optimización de tipos de datos en el dataset.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')

# %% [markdown]
# * `insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')`: Lee el archivo CSV de Instagram desde la ruta especificada en Drive y lo asigna a la variable `insta`.

# %%
insta.head()

# %% [markdown]
# * `insta.head()`: Muestra las primeras 5 filas del DataFrame `insta`.

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv")

# %% [markdown]
# * `insta = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv")`: Lee el archivo CSV de perfiles de Instagram desde Google Drive y lo carga en el DataFrame `insta`.

# %%
insta

# %% [markdown]
# * `insta`: Imprime en pantalla la visualización del DataFrame `insta`.

# %%
insta["reg date"] = pd.to_datetime(insta["reg date"])

# %% [markdown]
# * `insta["reg date"] = pd.to_datetime(insta["reg date"])`: Convierte la columna `"reg date"` a formato de fecha y hora (`datetime64`) usando `pd.to_datetime()`.

# %%
insta

# %% [markdown]
# * `insta`: Imprime en pantalla la visualización del DataFrame `insta`.

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta["last login"] = pd.to_datetime(insta["last login"])

# %% [markdown]
# * `insta["last login"] = pd.to_datetime(insta["last login"])`: Convierte la columna de texto `"last login"` a tipo fecha/hora (`datetime64`) utilizando la función `pd.to_datetime()`.

# %%
#insta.drop("last login", axis = 1, inplace = True)

# %% [markdown]
# * `#insta.drop("last login", axis = 1, inplace = True)`: Línea comentada que muestra cómo se eliminaría la columna "last login" con el método `.drop()`.

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta["gender"].nunique()

# %% [markdown]
# * `insta["gender"].nunique()`: Calcula y devuelve la cantidad de valores únicos y distintos existentes en la columna `"gender"`.

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta["gender"].astype("category")

# %% [markdown]
# * `insta["gender"].astype("category")`: Crea una versión temporal de la columna `"gender"` convertida a tipo categórico sin alterar la columna original.

# %%
insta["gender"] = insta["gender"].astype("category")

# %% [markdown]
# * `insta["gender"] = insta["gender"].astype("category")`: Transforma la columna `"gender"` a tipo categórico (`"category"`), guardando el cambio directamente en la misma columna.

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta["Country"]

# %% [markdown]
# * `insta["Country"]`: Selecciona y muestra los datos de la columna `"Country"` del DataFrame `insta`.
