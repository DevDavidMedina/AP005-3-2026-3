# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy13

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# * `nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')`: Lee el archivo de Excel ubicado en la ruta de Google Drive y lo almacena en la variable `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba["Team"].value_counts()

# %% [markdown]
# * `nba["Team"].value_counts()`: Calcula y despliega la cantidad de veces que se repite cada equipo en la columna `"Team"`, ordenado descendentemente.

# %%
#nba["Division"].value_counts()

# %% [markdown]
# * `#nba["Division"].value_counts()`: Línea comentada que muestra el conteo de frecuencias de la columna `Division` en su orden por defecto (descendente).

# %%
nba["Division"].value_counts(ascending = True)

# %% [markdown]
# * `nba["Division"].value_counts(ascending = True)`: Cuenta la frecuencia de cada valor en `"Division"` ordenando los resultados de menor a mayor (`ascending=True`).
