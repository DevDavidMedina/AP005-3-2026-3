# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy6

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("Nba Teams.xlsx")`: Carga el archivo local `Nba Teams.xlsx` en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba[["Name", "Team"]]

# %% [markdown]
# * `nba[["Name", "Team"]]`: Selecciona y devuelve un nuevo DataFrame con únicamente las columnas `"Name"` y `"Team"`.

# %%
nba[["Name", "Team", "Salary"]]

# %% [markdown]
# * `nba[["Name", "Team", "Salary"]]`: Filtra y extrae un sub-DataFrame compuesto exclusivamente por las tres columnas especificadas: `"Name"`, `"Team"` y `"Salary"`.
