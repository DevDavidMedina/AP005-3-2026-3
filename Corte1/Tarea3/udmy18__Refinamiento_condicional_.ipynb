# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy18__Refinamiento_condicional_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy18 (Refinamiento condicional)

# %%
#Refine Dataset by a Condition

# %% [markdown]
# * `#Refine Dataset by a Condition`: Comentario que indica la sección de refinamiento o filtrado del DataFrame mediante una condición.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')

# %% [markdown]
# * `insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')`: Lee el archivo CSV de Instagram desde la ruta especificada en Drive y lo asigna a la variable `insta`.

# %%
insta["reg date"] = pd.to_datetime(insta["reg date"])

# %% [markdown]
# * `insta["reg date"] = pd.to_datetime(insta["reg date"])`: Convierte la columna `"reg date"` a formato de fecha y hora (`datetime64`) usando `pd.to_datetime()`.

# %%
insta["last login"] = pd.to_datetime(insta["last login"])

# %% [markdown]
# * `insta["last login"] = pd.to_datetime(insta["last login"])`: Convierte la columna de texto `"last login"` a tipo fecha/hora (`datetime64`) utilizando la función `pd.to_datetime()`.

# %%
insta["gender"] = insta["gender"].astype("category")

# %% [markdown]
# * `insta["gender"] = insta["gender"].astype("category")`: Transforma la columna `"gender"` a tipo categórico (`"category"`), guardando el cambio directamente en la misma columna.

# %%
insta["Country"] = insta["Country"].astype("category")

# %% [markdown]
# * `insta["Country"] = insta["Country"].astype("category")`: Convierte la columna `"Country"` al tipo de datos `"category"` para optimizar el rendimiento y reducir el uso de memoria.

# %%
insta["Influencer"] = insta["Influencer"].astype("bool")

# %% [markdown]
# * `insta["Influencer"] = insta["Influencer"].astype("bool")`: Convierte la columna `"Influencer"` al tipo de dato booleano nativo (`"bool"`).

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])

# %% [markdown]
# * `insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])`: Lee el CSV de Instagram analizando y convirtiendo automáticamente las columnas `"reg date"` y `"last login"` al formato de fecha y hora nativo (`datetime`).

# %%
insta["gender"] = insta["gender"].astype("category")

# %% [markdown]
# * `insta["gender"] = insta["gender"].astype("category")`: Transforma la columna `"gender"` a tipo categórico (`"category"`), guardando el cambio directamente en la misma columna.

# %%
insta["Country"] = insta["Country"].astype("category")

# %% [markdown]
# * `insta["Country"] = insta["Country"].astype("category")`: Convierte la columna `"Country"` al tipo de datos `"category"` para optimizar el rendimiento y reducir el uso de memoria.

# %%
insta["Influencer"] = insta["Influencer"].astype("bool")

# %% [markdown]
# * `insta["Influencer"] = insta["Influencer"].astype("bool")`: Convierte la columna `"Influencer"` al tipo de dato booleano nativo (`"bool"`).

# %%
insta.info()

# %% [markdown]
# * `insta.info()`: Muestra el resumen estructural del DataFrame `insta` para inspeccionar tipos de datos y consumo de memoria.

# %%
insta.head(3)

# %% [markdown]
# * `insta.head(3)`: Muestra únicamente las primeras 3 filas del DataFrame `insta`.

# %%
insta[insta["gender"] == "Male"]

# %% [markdown]
# * `insta[insta["gender"] == "Male"]`: Filtra y muestra en pantalla únicamente los usuarios cuyo género registrado sea `"Male"`.

# %%
insta[insta["Country"] == "Australia"]

# %% [markdown]
# * `insta[insta["Country"] == "Australia"]`: Filtra y extrae todas las filas del DataFrame `insta` cuyo país sea exactamente `"Australia"`.

# %%
mask = insta["gender"] == "Female"

# %% [markdown]
# * `mask = insta["gender"] == "Female"`: Genera la Serie booleana `mask` donde cada valor es `True` si el usuario es de género femenino (`"Female"`).

# %%
insta[mask]

# %% [markdown]
# * `insta[mask]`: Aplica la máscara booleana `mask` para filtrar y desplegar los registros que cumplen las condiciones establecidas.

# %%
mask = insta["gender"] == "Female"

# %% [markdown]
# * `mask = insta["gender"] == "Female"`: Genera la Serie booleana `mask` donde cada valor es `True` si el usuario es de género femenino (`"Female"`).

# %%
insta[mask]

# %% [markdown]
# * `insta[mask]`: Aplica la máscara booleana `mask` para filtrar y desplegar los registros que cumplen las condiciones establecidas.

# %%
mask1 = insta["Country"] != "United States"

# %% [markdown]
# * `mask1 = insta["Country"] != "United States"`: Genera una condición booleana con el operador de desigualdad (`!=`) para seleccionar registros cuyo país no sea `"United States"`.

# %%
insta[mask1]

# %% [markdown]
# * `insta[mask1]`: Aplica el filtro condicional `mask1` para desplegar las filas que cumplen dicha regla.
