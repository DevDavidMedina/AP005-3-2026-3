# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy4

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel('Nba Teams.xlsx')

# %% [markdown]
# * `nba = pd.read_excel('Nba Teams.xlsx')`: Lee el archivo de Excel `Nba Teams.xlsx` en el directorio de trabajo y lo asigna a `nba`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.info()

# %% [markdown]
# * `nba.info()`: Imprime el resumen con la cantidad de filas, columnas, datos no nulos y tipos de datos del DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba.head(5).info()

# %% [markdown]
# * `nba.head(5).info()`: Extrae las primeras 5 filas del DataFrame mediante `.head(5)` y aplica `.info()` sobre ese subconjunto para mostrar su estructura.
