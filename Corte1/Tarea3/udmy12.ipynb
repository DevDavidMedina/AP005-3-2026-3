# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy12

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# * `nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')`: Lee el archivo de Excel ubicado en la ruta de Google Drive y lo almacena en la variable `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba["Salary"]

# %% [markdown]
# * `nba["Salary"]`: Extrae y selecciona la columna `"Salary"` del DataFrame `nba`.

# %%
nba["Salary"].add(50000)

# %% [markdown]
# * `nba["Salary"].add(50000)`: Aplica el método matemático `.add()` para sumar 50,000 a todos los registros numéricos de la columna `"Salary"`.

# %%
nba["Salary"] + 2000000

# %% [markdown]
# * `nba["Salary"] + 2000000`: Suma vectorialmente 2,000,000 a cada valor de la columna `"Salary"` utilizando el operador aritmético `+`.

# %%
nba["bonus_salary"] = nba["Salary"] + 30000

# %% [markdown]
# * `nba["bonus_salary"] = nba["Salary"] + 30000`: Crea una nueva columna `"bonus_salary"` calculada sumando 30,000 al valor existente de `"Salary"`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba["Salary"].sub(55000)

# %% [markdown]
# * `nba["Salary"].sub(55000)`: Aplica el método `.sub()` para restar 55,000 a cada elemento de la columna `"Salary"`.

# %%
#nba["Salary"] - sub(55000)

# %% [markdown]
# * `#nba["Salary"] - sub(55000)`: Línea comentada que muestra una sintaxis errónea/alternativa al intentar restar 55000 a la columna `Salary`.

# %%
nba["Salary"].div(1000000)

# %% [markdown]
# * `nba["Salary"].div(1000000)`: Aplica el método `.div()` para dividir entre 1,000,000 cada valor de la Serie `"Salary"`.

# %%
#nba["Salary"]/1000000

# %% [markdown]
# * `#nba["Salary"]/1000000`: Línea comentada que ilustra la división vectorizada de la columna `Salary` entre 1 millón usando el operador `/`.

# %%
nba["Weight"].mul(0.453592)

# %% [markdown]
# * `nba["Weight"].mul(0.453592)`: Multiplica vectorialmente cada valor de la columna `"Weight"` por 0.453592 con `.mul()` para transformar libras a kilogramos.

# %%
#nba["Weight"]*0.453592

# %% [markdown]
# * `#nba["Weight"]*0.453592`: Línea comentada que muestra la multiplicación directa con el operador `*` para convertir pesos de libras a kilogramos.
