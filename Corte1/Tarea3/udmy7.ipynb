# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy7

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("Nba Teams.xlsx")`: Carga el archivo local `Nba Teams.xlsx` en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba["Teams"] = " "

# %% [markdown]
# * `nba["Teams"] = " "`: Crea o sobrescribe la columna `"Teams"` inicializándola con un espacio en blanco en cada fila.

# %%
nba["nba Teams"] = " "

# %% [markdown]
# * `nba["nba Teams"] = " "`: Crea una nueva columna denominada `"nba Teams"` inicializada con un espacio en blanco en todas las filas.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
#nba.Name

# %% [markdown]
# * `#nba.Name`: Línea comentada que muestra el acceso a la columna `Name` usando la sintaxis de atributo por punto.

# %%
#nba.nba Teams

# %% [markdown]
# * `#nba.nba Teams`: Línea comentada que evidencia que la notación de punto falla cuando los nombres de columna contienen espacios.

# %%
nba.Teams

# %% [markdown]
# * `nba.Teams`: Accede a la columna `"Teams"` utilizando la notación de punto.

# %%
#nba.Sports

# %% [markdown]
# * `#nba.Sports`: Línea comentada que muestra el intento de acceso a la columna `Sports` mediante notación de punto.

# %%
nba["Sports"] = "basket"

# %% [markdown]
# * `nba["Sports"] = "basket"`: Crea una columna nueva denominada `"Sports"` asignándole el valor constante `"basket"` a todas sus filas.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba.drop("Teams", axis = 1, inplace = True)

# %% [markdown]
# * `nba.drop("Teams", axis = 1, inplace = True)`: Elimina la columna `"Teams"` permanentemente del DataFrame utilizando `axis=1` y el argumento `inplace=True`.

# %%
#nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# * `#nba.insert(2, column = "Teams", value = "Colombians")`: Línea comentada que muestra la inserción de la columna "Teams" con el valor "Colombians".

# %%
#nba.insert(2, column = "Sportss", value = "Turmequé")

# %% [markdown]
# * `#nba.insert(2, column = "Sportss", value = "Turmequé")`: Línea comentada que muestra cómo insertar una columna llamada "Sportss" en la posición 2 con el valor "Turmequé".

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# * `nba.insert(2, column = "Teams", value = "Colombians")`: Inserta una nueva columna `"Teams"` en la posición de índice 2 (tercera columna) asignándole el valor constante `"Colombians"`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.
