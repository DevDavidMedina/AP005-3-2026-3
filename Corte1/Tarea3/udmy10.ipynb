# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy10

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")`: Lee el archivo Excel de equipos de la NBA desde una carpeta específica en Drive y lo carga en la variable `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba.head(10)

# %% [markdown]
# * `nba.head(10)`: Muestra las primeras 10 filas del DataFrame `nba`.

# %%
nba.tail()

# %% [markdown]
# * `nba.tail()`: Muestra las últimas 5 filas del DataFrame `nba`.

# %%
nbaNoNull = nba.dropna()

# %% [markdown]
# * `nbaNoNull = nba.dropna()`: Crea un nuevo DataFrame llamado `nbaNoNull` asignándole el resultado de filtrar las filas con valores nulos mediante `.dropna()`.

# %%
nbaNoNull

# %% [markdown]
# * `nbaNoNull`: Imprime en pantalla el contenido del DataFrame filtrado `nbaNoNull`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
#nba.dropna(inplace=True)

# %% [markdown]
# * `#nba.dropna(inplace=True)`: Línea comentada que muestra la sintaxis para eliminar filas con valores nulos directamente sobre el DataFrame original usando `inplace=True`.

# %%
nba.dropna()

# %% [markdown]
# * `nba.dropna()`: Ejecuta la eliminación temporal de filas que contengan al menos un valor nulo (`NaN`), devolviendo un nuevo DataFrame.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.info()

# %% [markdown]
# * `nba.info()`: Imprime el resumen con la cantidad de filas, columnas, datos no nulos y tipos de datos del DataFrame `nba`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.dropna(how="all")

# %% [markdown]
# * `nba.dropna(how="all")`: Elimina únicamente las filas donde absolutamente todos sus campos sean valores nulos (`how="all"`).

# %%
nba.dropna(axis = 0)

# %% [markdown]
# * `nba.dropna(axis = 0)`: Evalúa y descarta las filas (`axis=0`) que contengan al menos un valor nulo.

# %%
nba.dropna(axis=1)

# %% [markdown]
# * `nba.dropna(axis=1)`: Evalúa y descarta las columnas (`axis=1`) completas que contengan al menos un valor nulo.

# %%
nba.dropna(subset = ["Name", "Salary", "College"])

# %% [markdown]
# * `nba.dropna(subset = ["Name", "Salary", "College"])`: Elimina las filas que contengan valores nulos únicamente evaluando las columnas listadas en el parámetro `subset`.
