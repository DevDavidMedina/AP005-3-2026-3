# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy16__Employee_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy16 (Employee dataset)

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")

# %% [markdown]
# * `emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")`: Lee el archivo CSV de empleados desde la ruta indicada en Google Drive y lo asigna a la variable `emp`.

# %%
emp.head()

# %% [markdown]
# * `emp.head()`: Muestra las 5 primeras filas del DataFrame `emp`.

# %%
emp.info()

# %% [markdown]
# * `emp.info()`: Imprime la información estructural del DataFrame `emp`, incluyendo tipos de datos y consumo de memoria RAM.

# %%
emp.nunique()

# %% [markdown]
# * `emp.nunique()`: Calcula y muestra la cantidad exacta de valores únicos existentes para cada columna del DataFrame `emp`.

# %%
emp[["department", "position"]] = emp[["department", "position"]].astype("category")

# %% [markdown]
# * `emp[["department", "position"]] = emp[["department", "position"]].astype("category")`: Convierte el tipo de dato de las columnas `"department"` y `"position"` a tipo categórico (`"category"`) para optimizar el uso de memoria RAM.

# %%
emp.info()

# %% [markdown]
# * `emp.info()`: Imprime la información estructural del DataFrame `emp`, incluyendo tipos de datos y consumo de memoria RAM.

# %%
"happy".upper()

# %% [markdown]
# * `"happy".upper()`: Aplica el método de cadena `.upper()` al string `"happy"`, convirtiendo todas sus letras a mayúsculas (`"HAPPY"`).

# %%
"PYTHON".lower()

# %% [markdown]
# * `"PYTHON".lower()`: Aplica el método de cadena `.lower()` al string `"PYTHON"`, convirtiendo todas sus letras a minúsculas (`"python"`).

# %%
emp["name"]

# %% [markdown]
# * `emp["name"]`: Selecciona y extrae la columna `"name"` del DataFrame `emp` como un objeto Serie.

# %%
emp["name"].str.lower().str.title()

# %% [markdown]
# * `emp["name"].str.lower().str.title()`: Encadena dos métodos de texto sobre la Serie `"name"`: primero convierte todo a minúsculas con `.str.lower()` y luego capitaliza cada palabra con `.str.title()`.
