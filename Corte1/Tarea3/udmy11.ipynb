# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy11

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# * `nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')`: Lee el archivo de Excel ubicado en la ruta de Google Drive y lo almacena en la variable `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba.head(10)

# %% [markdown]
# * `nba.head(10)`: Muestra las primeras 10 filas del DataFrame `nba`.

# %%
nba.fillna(0)

# %% [markdown]
# * `nba.fillna(0)`: Reemplaza de forma global todos los valores nulos (`NaN`) en el DataFrame por el valor numérico `0`.

# %%
nba[["College"]].fillna(0, inplace = True)

# %% [markdown]
# * `nba[["College"]].fillna(0, inplace = True)`: Intenta rellenar con 0 los valores nulos en la columna `"College"` utilizando la sintaxis de DataFrame de doble corchete con `inplace=True`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba["Name"].fillna("Missing name", inplace = True)

# %% [markdown]
# * `nba["Name"].fillna("Missing name", inplace = True)`: Rellena permanentemente (`inplace=True`) los valores nulos de la columna `"Name"` con la cadena `"Missing name"`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.
