# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy15

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# * `nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')`: Lee el archivo de Excel ubicado en la ruta de Google Drive y lo almacena en la variable `nba`.

# %%
nba.sort_values(["Team", "Name"], na_position = "first", inplace = True)

# %% [markdown]
# * `nba.sort_values(["Team", "Name"], na_position = "first", inplace = True)`: Ordena por equipo y nombre colocando los valores nulos al principio (`na_position="first"`) y guarda los cambios de forma definitiva con `inplace=True`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba.sort_index()

# %% [markdown]
# * `nba.sort_index()`: Reorganiza y restaura el orden de las filas del DataFrame tomando como referencia su índice numérico original.
