# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"

# %% [markdown]
# * `url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"`: Define la variable `url` asignándole como valor la dirección URL del archivo CSV con registros de COVID en la ciudad de Nueva York.

# %%
#covid = pd.read_csv(url)

# %% [markdown]
# * `#covid = pd.read_csv(url)`: Línea comentada (desactivada) que contiene una llamada previa para leer el archivo CSV desde la URL.

# %%
covid = pd.read_csv(url)

# %% [markdown]
# * `covid = pd.read_csv(url)`: Llama a la función `pd.read_csv()` pasando la variable `url` para leer el archivo CSV remoto y asignarlo a la variable `covid`.

# %%
covid.head()

# %% [markdown]
# * `covid.head()`: Invoca el método `.head()` sobre el DataFrame `covid` para mostrar sus primeras 5 filas.

# %%
covid.info()

# %% [markdown]
# * `covid.info()`: Ejecuta el método `.info()` sobre el DataFrame `covid` para imprimir un resumen detallado con número de columnas, nombres, conteo de no nulos y tipos de datos.

# %%
covid.to_csv('NYC_covid_cases.csv')

# %% [markdown]
# * `covid.to_csv('NYC_covid_cases.csv')`: Guarda todo el contenido del DataFrame `covid` en un archivo CSV local denominado `"NYC_covid_cases.csv"`.

# %%
covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])

# %% [markdown]
# * `covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])`: Exporta el DataFrame `covid` a un archivo CSV local llamado `"NYC1_covid_cases.csv"`, filtrando únicamente las columnas especificadas en la lista del parámetro `columns`.
