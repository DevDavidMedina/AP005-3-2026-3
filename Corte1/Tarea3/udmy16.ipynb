# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy16

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
#nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# * `#nba = pd.read_excel("Nba Teams.xlsx")`: Línea comentada que contiene la lectura del archivo Excel desde el directorio local.

# %%
nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx").dropna(how = "all")

# %% [markdown]
# * `nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx").dropna(how = "all")`: Carga el archivo Excel desde Google Drive y encadena inmediatamente `.dropna(how="all")` para descartar filas completamente vacías desde el inicio.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba.info()

# %% [markdown]
# * `nba.info()`: Imprime el resumen con la cantidad de filas, columnas, datos no nulos y tipos de datos del DataFrame `nba`.

# %%
nba["Height"].fillna("Missing")

# %% [markdown]
# * `nba["Height"].fillna("Missing")`: Reemplaza de forma temporal los valores nulos existentes en la columna `"Height"` por la cadena de texto `"Missing"`.
