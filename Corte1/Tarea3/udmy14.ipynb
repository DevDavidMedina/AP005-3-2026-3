# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy14

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx")`: Lee el archivo Excel `Nba Teams.xlsx` desde Google Drive y lo asigna al DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
from google.colab import drive

# %% [markdown]
# * `from google.colab import drive`: Importa el módulo `drive` desde el paquete `google.colab` para permitir la integración con Google Drive.

# %%
drive.mount('/content/drive')

# %% [markdown]
# * `drive.mount('/content/drive')`: Ejecuta el asistente de Google Colab para autenticar y montar la unidad de almacenamiento Google Drive en el directorio `/content/drive`.

# %%
nba.sort_values("Name").head(20)

# %% [markdown]
# * `nba.sort_values("Name").head(20)`: Ordena las filas alfabéticamente según la columna `"Name"` y extrae las 20 primeras con `.head(20)`.

# %%
nba.sort_values("Salary")

# %% [markdown]
# * `nba.sort_values("Salary")`: Ordena el DataFrame numéricamente de forma ascendente tomando como criterio la columna `"Salary"`.

# %%
#nba.sort_values("Salary", ascending = False, inplace = True)

# %% [markdown]
# * `#nba.sort_values("Salary", ascending = False, inplace = True)`: Línea comentada con el comando para ordenar por salario de forma descendente y guardar el cambio en el DataFrame original.

# %%
nba.sort_values(["Team", "Name"])

# %% [markdown]
# * `nba.sort_values(["Team", "Name"])`: Ordena el DataFrame según múltiples criterios: primero por equipo (`Team`) y dentro de cada equipo por nombre (`Name`).

# %%
#nba.sort_values(["Team", "Name"], na_position = 'first')

# %% [markdown]
# * `#nba.sort_values(["Team", "Name"], na_position = 'first')`: Línea comentada que muestra cómo ordenar por equipo y nombre colocando los valores nulos al principio.
