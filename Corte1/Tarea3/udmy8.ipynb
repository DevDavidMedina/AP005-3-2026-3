# %% [markdown]
# <a href="https://colab.research.google.com/github/DevDavidMedina/AP005-3-2026-3/blob/main/Corte1/Tarea3/udmy8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # udmy8

# %%
import pandas as pd

# %% [markdown]
# * `import pandas as pd`: Importa la biblioteca de análisis de datos Pandas asignándole el alias estándar `pd`.

# %%
nba = pd.read_excel("Nba Teams.xlsx")

# %% [markdown]
# * `nba = pd.read_excel("Nba Teams.xlsx")`: Carga el archivo local `Nba Teams.xlsx` en el DataFrame `nba`.

# %%
nba.head()

# %% [markdown]
# * `nba.head()`: Muestra las primeras 5 filas del DataFrame `nba`.

# %%
nba.drop("Salary", axis = 1)

# %% [markdown]
# * `nba.drop("Salary", axis = 1)`: Elimina temporalmente la columna `"Salary"` (`axis=1`) generando una copia en memoria sin modificar la variable `nba`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.drop("Salary", axis = 1, inplace = True)

# %% [markdown]
# * `nba.drop("Salary", axis = 1, inplace = True)`: Elimina de forma permanente (`inplace=True`) la columna `"Salary"` (`axis=1`) del DataFrame `nba`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.

# %%
nba.drop(["Team", "Division"], axis = 1, inplace = True)

# %% [markdown]
# * `nba.drop(["Team", "Division"], axis = 1, inplace = True)`: Elimina de forma permanente las columnas `"Team"` y `"Division"` pasando una lista de nombres con `axis=1` e `inplace=True`.

# %%
nba

# %% [markdown]
# * `nba`: Muestra el contenido completo o resumido del DataFrame `nba`.
